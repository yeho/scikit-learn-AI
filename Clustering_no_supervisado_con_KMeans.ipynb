# %% [markdown]
# <a href="https://colab.research.google.com/github/yeho/scikit-learn-AI/blob/master/Clustering_no_supervisado_con_KMeans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
# Generar datos simulados
X, _ = make_blobs(n_samples=300, centers=4, random_state=42)
# Modelo no supervisado
kmeans = KMeans(n_clusters=4)
kmeans.fit(X)
y_pred = kmeans.predict(X)
# Visualización
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.title("Clustering con KMeans")
plt.show()
