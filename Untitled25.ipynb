# %% [markdown]
# <a href="https://colab.research.google.com/github/yeho/scikit-learn-AI/blob/master/Untitled25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers torch

import torch

from transformers import AutoTokenizer, AutoModelForCausalLM
model_name = "gpt2"

tokenizer = AutoTokenizer.from_pretrained(model_name)

model = AutoModelForCausalLM.from_pretrained(model_name)
prompt = "La inteligencia artificial aplicada al lenguaje natural"

inputs = tokenizer(prompt, return_tensors="pt")

outputs = model.generate(

**inputs,

max_length=60,

do_sample=True,

temperature=0.8,

top_k=50

)

generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

print(generated_text)
# Out:
# ...
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# La inteligencia artificial aplicada al lenguaje natural aplicada para esta non esta nueva, para quiere o nueva a una ella esta non esta, a prada qué aunque ella esta non

# %%
outputs = model.generate(

**inputs,

max_length=80,

do_sample=True,

temperature=1.1,

top_k=100

)

print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# La inteligencia artificial aplicada al lenguaje natural del hombre la loquefania de los diabolicias un terraza para esta.
#
# Proto - En. Proto hortuto
#
# Hortu vos de la vota en el nueva pisotima española muy pepos:
